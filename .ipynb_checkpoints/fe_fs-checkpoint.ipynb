# %% [markdown]
# # Dry Beans Classification
#
# ## Solutions
#
# * Outlier Elimination
# * Elimitene highly correlated independent features

# %% [markdown]
# ## Load Necessary Libraries

# %%
import pandas as pd
import numpy as np
import os
import statsmodels.api as sm
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import VarianceThreshold

# %% [markdown]
# ## Load Dataset

# %%
folder_path = "/content/drive/MyDrive/Colab Notebooks/dscourse/dry_bins_classification"
# folder_path = "./"
file_path = os.path.join(folder_path, "Dry_Bean_Dataset.xlsx")
df= pd.read_excel(file_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-68d0e03dd465> in <cell line: 4>()
#       2 # folder_path = "./"
#       3 file_path = os.path.join(folder_path, "Dry_Bean_Dataset.xlsx")
# ----> 4 df= pd.read_excel(file_path)
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend)
#     476     if not isinstance(io, ExcelFile):
#     477         should_close = True
# --> 478         io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     479     elif engine and engine != io.engine:
#     480         raise ValueError(
#
# ...

# %%
# Encode the target
le = LabelEncoder()
df_en = df.copy()
df_en["Class"] = le.fit_transform(df_en["Class"])

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# Feature selection using correlation analysis
corr = df_en.corr()
corr
# Out:
#                      Area  Perimeter  MajorAxisLength  MinorAxisLength  \
# Area             1.000000   0.966722         0.931834         0.951602
# Perimeter        0.966722   1.000000         0.977338         0.913179
# MajorAxisLength  0.931834   0.977338         1.000000         0.826052
# MinorAxisLength  0.951602   0.913179         0.826052         1.000000
# AspectRation     0.241735   0.385276         0.550335        -0.009161
# Eccentricity     0.267481   0.391066         0.541972         0.019574
# ConvexArea       0.999939   0.967689         0.932607         0.951339
# EquivDiameter    0.984968   0.991380         0.961733         0.948539
# Extent           0.054345  -0.021160        -0.078062         0.145957
# Solidity        -0.196585  -0.303970        -0.284302        -0.155831
# roundness       -0.357530  -0.547647        -0.596358        -0.210344
# Compactness     -0.268067  -0.406857        -0.568377        -0.015066
# ...

# %%
# Select the features having correlation with target above 0.2
corr_target = corr["Class"].abs()

# Define threshold
threshold= 0.2

selected_features = corr_target[corr_target > threshold].index
selected_features
# Out:
# Index(['Area', 'Perimeter', 'MajorAxisLength', 'MinorAxisLength',
#        'Eccentricity', 'ConvexArea', 'EquivDiameter', 'Solidity', 'roundness',
#        'ShapeFactor1', 'ShapeFactor2', 'Class'],
#       dtype='object')

# %%
# Dataframe with selected features
df_corr = df[selected_features]
df_corr
# Out:
#         Area  Perimeter  MajorAxisLength  MinorAxisLength  Eccentricity  \
# 0      28395    610.291       208.178117       173.888747      0.549812
# 1      28734    638.018       200.524796       182.734419      0.411785
# 2      29380    624.110       212.826130       175.931143      0.562727
# 3      30008    645.884       210.557999       182.516516      0.498616
# 4      30140    620.134       201.847882       190.279279      0.333680
# ...      ...        ...              ...              ...           ...
# 13606  42097    759.696       288.721612       185.944705      0.765002
# 13607  42101    757.499       281.576392       190.713136      0.735702
# 13608  42139    759.321       281.539928       191.187979      0.734065
# 13609  42147    763.779       283.382636       190.275731      0.741055
# 13610  42159    772.237       295.142741       182.204716      0.786693
#
#        ConvexArea  EquivDiameter  Solidity  roundness  ShapeFactor1  \
# ...

# %%
# Write to CSV
df_corr.to_csv("db_class_corr.csv", index=False)

# %%
def evaluate_model():
  # Separate the features
  X= df_en.iloc[:, :-1]
  y= df_en.iloc[:, -1]

  # Add constant
  X= sm.add_constant(X)

  # Build the model
  model = sm.OLS(y, X).fit()

  print(f"{model.pvalues.idxmax()} has the highest P-Value: {model.pvalues.max()}")
  if model.pvalues.max() > 0.05:
    print(f"{model.pvalues.idxmax()} should be eliminated")

# %%
evaluate_model()
# Out:
# ShapeFactor4 has the highest P-Value: 0.6854540174054453
# ShapeFactor4 should be eliminated

# %%
df1 = df.drop("ShapeFactor4", axis= 1)
df1.to_csv("db_class_1.csv", index=False)

# %%
# Fearures selction using variance threshold
threshold= 0.1
vt = VarianceThreshold(threshold= threshold)
X= df.iloc[:, :-1]
X_selected= vt.fit_transform(X)
selected_features = X.columns[vt.get_support(indices=True)]
features= list(selected_features)
features.append("Class")
features
# Out:
# ['Area',
#  'Perimeter',
#  'MajorAxisLength',
#  'MinorAxisLength',
#  'ConvexArea',
#  'EquivDiameter',
#  'Class']

# %%
df_var= df[features]
df_var.to_csv("db_class_var.csv", index=False)
